# %%
import requests
import time
import pandas as pd

# %%
def reconstruct_abstract(inverted_index):
    """
    Reconstructs the abstract text from an inverted index.
    The inverted index is a dict mapping words to lists of positions.
    """
    if not isinstance(inverted_index, dict) or not inverted_index:
        return "No abstract available"
    max_index = max(pos for positions in inverted_index.values() for pos in positions)
    words = [None] * (max_index + 1)
    for word, positions in inverted_index.items():
        for pos in positions:
            words[pos] = word
    return " ".join(w for w in words if w is not None)

# %%
def get_author_id(author_name):
    """
    Given a researcher name, query the OpenAlex Authors API to return the canonical author ID.
    """
    url = "https://api.openalex.org/authors"
    params = {"search": author_name, "per_page": 1}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        results = data.get("results", [])
        if results:
            # Returns a URL like "https://openalex.org/A1969200700"
            return results[0].get("id")
        else:
            return None
    except Exception as e:
        print(f"Error fetching author ID for '{author_name}': {e}")
        return None

# %%
def query_openalex_by_researcher_datasets(author_id, dataset_terms, per_page=50, max_pages=3):
    """
    For a given author (by canonical ID) and a list of dataset terms, build a combined filter
    that uses the OR operator for the dataset terms (with each term wrapped in quotation marks)
    and query the OpenAlex Works API.
    """
    base_url = "https://api.openalex.org/works"
    # Wrap each dataset term in quotes and join using OR.
    or_query = " OR ".join([f'"{term}"' for term in dataset_terms])
    filter_str = f"default.search:({or_query}),authorships.author.id:{author_id}"

    works = []
    for page in range(1, max_pages + 1):
        params = {
            "page": page,
            "filter": filter_str,
            "sort": "relevance_score:desc",
            "per_page": per_page
        }
        # Construct the full query URL for printing.
        query_url = f"{base_url}?page={page}&filter={filter_str}&sort=relevance_score:desc&per_page={per_page}"
        print(f"API Request: {query_url}")
        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()
            data = response.json()
            page_results = data.get("results", [])
            if not page_results:
                break
            works.extend(page_results)
            time.sleep(1)  # Pause to respect rate limits.
        except Exception as e:
            print(f"Error querying for datasets '{or_query}' and author '{author_id}': {e}")
            break
    return works

# %%
def check_individual_dataset_matches(work, dataset_terms):
    """
    Given a work record and a list of dataset terms, check which of these terms are found
    in the combined text of the title and the reconstructed abstract.
    Returns a list of matched dataset terms.
    """
    # Ensure title is a string even if None
    title = work.get("title") or ""
    inv_index = work.get("abstract_inverted_index")
    abstract = reconstruct_abstract(inv_index) if inv_index else ""
    combined_text = (title + " " + abstract).lower()
    matches = [term for term in dataset_terms if term.lower() in combined_text]
    return matches

# %%
def process_work(work):
    """
    Extract the required fields from an OpenAlex work record.
    Adds the publication_date (if available), source display name, and type_crossref.
    """
    title = work.get("title", "")
    doi = work.get("doi", "")
    inv_index = work.get("abstract_inverted_index")
    abstract = reconstruct_abstract(inv_index) if inv_index else "No abstract available"
    year = work.get("publication_year", "")
    # Extract full publication date if available.
    publication_date = work.get("publication_date", "")
    cited_by_count = work.get("cited_by_count", "")

    # Process authors and affiliations.
    authors_list = []
    affiliations_list = []
    for authorship in work.get("authorships", []):
        author_name = authorship.get("author", {}).get("display_name", "")
        if author_name:
            authors_list.append(author_name)
        institutions = authorship.get("institutions", [])
        inst_names = [inst.get("display_name", "") for inst in institutions if inst.get("display_name", "")]
        if inst_names:
            affiliations_list.append("; ".join(inst_names))
    authors_str = "; ".join(authors_list)
    affiliations_str = "; ".join(affiliations_list)

    # Extract topics
    topics = work.get("topics", [])
    topic_names = [t.get("display_name", "") for t in topics if t.get("display_name", "")]
    topics_str = "; ".join(topic_names)

    # Extract host venue details: source display name and type_crossref.
    host_venue = work.get("primary_location", {})  or {}
    source = host_venue.get("source", {})  or {}
    source_display_name = source.get("display_name",
                                     "")  if isinstance(source, dict) else ""
    type_crossref = work.get("type", "")  if work else ""

    return {
        "title": title,
        "doi": doi,
        "abstract": abstract,
        "year": year,
        "publication_date": publication_date,
        "cited_by_count": cited_by_count,
        "authors": authors_str,
        "affiliations": affiliations_str,
        "topics": topics_str,
        "source_display_name": source_display_name,
        "type_crossref": type_crossref
    }

# %%
def chunk_list(lst, chunk_size):
    """Yield successive chunks of size chunk_size from list lst."""
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

# %%
def main():
    # Read the CSV that has two columns: "researcher" and "dataset".
    df = pd.read_csv("dataset_data_test_small.csv")
    # Group by researcher and collect the unique dataset terms for each researcher.
    grouped = df.groupby("researcher")["dataset"].apply(lambda terms: list(set(terms))).reset_index()

    results = []
    # Cache for author IDs to avoid repeated lookups.
    author_cache = {}

    # Loop over each researcher.
    for idx, row in grouped.iterrows():
        researcher = row["researcher"]
        dataset_terms = row["dataset"]  # List of dataset terms for this researcher.
        print(f"Processing researcher '{researcher}' with {len(dataset_terms)} dataset terms.")

        # Retrieve the canonical author ID (or use cached value if available).
        if researcher in author_cache:
            author_id = author_cache[researcher]
        else:
            author_id = get_author_id(researcher)
            author_cache[researcher] = author_id

        if not author_id:
            print(f"  No OpenAlex ID found for researcher '{researcher}'. Skipping.")
            continue

        # Split the dataset terms into chunks of at most 4.
        for chunk in chunk_list(dataset_terms, 4):
            print(f"  Querying chunk: {chunk}")
            works = query_openalex_by_researcher_datasets(author_id, chunk)
            print(f"    Found {len(works)} works for chunk: {chunk}")
            for work in works:
                matched_terms = check_individual_dataset_matches(work, chunk)
                if matched_terms:
                    record = process_work(work)
                    record["researcher"] = researcher
                    record["author_id"] = author_id
                    record["queried_dataset_terms"] = "; ".join(chunk)
                    record["matched_dataset_terms"] = "; ".join(matched_terms)
                    results.append(record)
            time.sleep(1)  # Pause between chunks.
        time.sleep(2)  # Pause between researchers.

    # Save the results to a CSV file.
    output_df = pd.DataFrame(results)
    output_csv = "openalex_researcher_datasets_matches_test.csv"
    output_df.to_csv(output_csv, index=False)
    print(f"Saved {len(output_df)} matching records to {output_csv}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing researcher 'Alesha Istvan' with 2 dataset terms.
#   Querying chunk: ['American Community Survey', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("American Community Survey" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5009601989&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['American Community Survey', 'Decennial Census']
# Processing researcher 'Anupam Nanda' with 2 dataset terms.
#   Querying chunk: ['Decennial Census', 'American Housing Survey']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census" OR "American Housing Survey"),authorships.author.id:https://openalex.org/A5068093253&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Decennial Census" OR "American Housing Survey"),authorships.author.id:https://openalex.org/A5068093253&sort=relevance_score:desc&per_page=50
#     Found 1 works for chunk: ['Decennial Census', 'American Housing Survey']
# Processing researcher 'Caleb Floyd' with 2 dataset terms.
#   No OpenAlex ID found for researcher 'Caleb Floyd'. Skipping.
# Processing researcher 'Chris Fowler' with 3 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5081967097&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# Processing researcher 'David S Lee' with 3 dataset terms.
#   Querying chunk: ['Annual Survey of Manufactures', 'Census of Manufactures', 'Standard Statistical Establishment Listing']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Annual Survey of Manufactures" OR "Census of Manufactures" OR "Standard Statistical Establishment Listing"),authorships.author.id:https://openalex.org/A5100648333&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Annual Survey of Manufactures', 'Census of Manufactures', 'Standard Statistical Establishment Listing']
# Processing researcher 'David Van Riper' with 3 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5086899416&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5086899416&sort=relevance_score:desc&per_page=50
#     Found 4 works for chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# Processing researcher 'David Zeke' with 7 dataset terms.
#   Querying chunk: ['Compustat-SSEL Bridge', 'Longitudinal Business Database - No Revenue', 'Annual Survey of Manufactures', 'Census of Manufactures']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Compustat-SSEL Bridge" OR "Longitudinal Business Database - No Revenue" OR "Annual Survey of Manufactures" OR "Census of Manufactures"),authorships.author.id:https://openalex.org/A5078764668&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Compustat-SSEL Bridge', 'Longitudinal Business Database - No Revenue', 'Annual Survey of Manufactures', 'Census of Manufactures']
#   Querying chunk: ['Standard Statistical Establishment List - non Name and Address File', 'Quarterly Survey of Plant Capacity Utilization (formerly known as PCU)', 'Standard Statistical Establishment Listing']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Standard Statistical Establishment List - non Name and Address File" OR "Quarterly Survey of Plant Capacity Utilization (formerly known as PCU)" OR "Standard Statistical Establishment Listing"),authorships.author.id:https://openalex.org/A5078764668&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Standard Statistical Establishment List - non Name and Address File', 'Quarterly Survey of Plant Capacity Utilization (formerly known as PCU)', 'Standard Statistical Establishment Listing']
# Processing researcher 'Dennis Epple' with 1 dataset terms.
#   Querying chunk: ['Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5038327208&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5038327208&sort=relevance_score:desc&per_page=50
#     Found 1 works for chunk: ['Decennial Census']
# Processing researcher 'Gary J Gates' with 1 dataset terms.
#   Querying chunk: ['American Community Survey']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("American Community Survey"),authorships.author.id:https://openalex.org/A5084514910&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("American Community Survey"),authorships.author.id:https://openalex.org/A5084514910&sort=relevance_score:desc&per_page=50
#     Found 31 works for chunk: ['American Community Survey']
# Processing researcher 'Harland Prechel' with 2 dataset terms.
#   Querying chunk: ['American Community Survey', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("American Community Survey" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5035929151&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['American Community Survey', 'Decennial Census']
# Processing researcher 'Holger Sieg' with 1 dataset terms.
#   Querying chunk: ['Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5051573583&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5051573583&sort=relevance_score:desc&per_page=50
#     Found 1 works for chunk: ['Decennial Census']
# Processing researcher 'Ivan Rudik' with 3 dataset terms.
#   Querying chunk: ['Auxiliary Establishment - ES9200', 'Business Enterprise Research and Development Survey (BERD)', 'Census of Construction Industries']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Auxiliary Establishment - ES9200" OR "Business Enterprise Research and Development Survey (BERD)" OR "Census of Construction Industries"),authorships.author.id:https://openalex.org/A5065021032&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Auxiliary Establishment - ES9200', 'Business Enterprise Research and Development Survey (BERD)', 'Census of Construction Industries']
# Processing researcher 'James D Gaboardi' with 3 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5081784916&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5081784916&sort=relevance_score:desc&per_page=50
#     Found 2 works for chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# Processing researcher 'John Mark Ellis' with 1 dataset terms.
#   No OpenAlex ID found for researcher 'John Mark Ellis'. Skipping.
# Processing researcher 'Jonathan Schroeder' with 3 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5075565031&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# Processing researcher 'Katherine R Genadek' with 3 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5068285647&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5068285647&sort=relevance_score:desc&per_page=50
#     Found 8 works for chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# Processing researcher 'Katie R Genadek' with 3 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5068285647&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5068285647&sort=relevance_score:desc&per_page=50
#     Found 8 works for chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# Processing researcher 'Margaret Hudson' with 1 dataset terms.
#   Querying chunk: ['Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5036762825&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Decennial Census']
# Processing researcher 'Michael D Steinberger' with 1 dataset terms.
#   Querying chunk: ['American Community Survey']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("American Community Survey"),authorships.author.id:https://openalex.org/A5034756570&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("American Community Survey"),authorships.author.id:https://openalex.org/A5034756570&sort=relevance_score:desc&per_page=50
#     Found 1 works for chunk: ['American Community Survey']
# Processing researcher 'Michael Peress' with 1 dataset terms.
#   Querying chunk: ['Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5016218202&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Decennial Census']
# Processing researcher 'Molly Graber' with 2 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5102522918&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Master Address File Extract', 'Decennial Census']
# Processing researcher 'Patrick J Bayer' with 2 dataset terms.
#   Querying chunk: ['Decennial Census', 'American Housing Survey']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census" OR "American Housing Survey"),authorships.author.id:https://openalex.org/A5081932134&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Decennial Census" OR "American Housing Survey"),authorships.author.id:https://openalex.org/A5081932134&sort=relevance_score:desc&per_page=50
#     Found 12 works for chunk: ['Decennial Census', 'American Housing Survey']
# Processing researcher 'Richard A Wright' with 1 dataset terms.
#   Querying chunk: ['Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5080215478&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5080215478&sort=relevance_score:desc&per_page=50
#     Found 7 works for chunk: ['Decennial Census']
# Processing researcher 'Robert J Kurtzman' with 7 dataset terms.
#   Querying chunk: ['Compustat-SSEL Bridge', 'Longitudinal Business Database - No Revenue', 'Annual Survey of Manufactures', 'Census of Manufactures']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Compustat-SSEL Bridge" OR "Longitudinal Business Database - No Revenue" OR "Annual Survey of Manufactures" OR "Census of Manufactures"),authorships.author.id:https://openalex.org/A5074646930&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Compustat-SSEL Bridge', 'Longitudinal Business Database - No Revenue', 'Annual Survey of Manufactures', 'Census of Manufactures']
#   Querying chunk: ['Standard Statistical Establishment List - non Name and Address File', 'Quarterly Survey of Plant Capacity Utilization (formerly known as PCU)', 'Standard Statistical Establishment Listing']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Standard Statistical Establishment List - non Name and Address File" OR "Quarterly Survey of Plant Capacity Utilization (formerly known as PCU)" OR "Standard Statistical Establishment Listing"),authorships.author.id:https://openalex.org/A5074646930&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Standard Statistical Establishment List - non Name and Address File', 'Quarterly Survey of Plant Capacity Utilization (formerly known as PCU)', 'Standard Statistical Establishment Listing']
# Processing researcher 'Rolando A Rodriguez' with 2 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5000630484&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Master Address File Extract', 'Decennial Census']
# Processing researcher 'Shihe N Fu' with 2 dataset terms.
#   No OpenAlex ID found for researcher 'Shihe N Fu'. Skipping.
# Processing researcher 'Stephen L Ross' with 2 dataset terms.
#   Querying chunk: ['Decennial Census', 'American Housing Survey']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census" OR "American Housing Survey"),authorships.author.id:https://openalex.org/A5000220540&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Decennial Census" OR "American Housing Survey"),authorships.author.id:https://openalex.org/A5000220540&sort=relevance_score:desc&per_page=50
#     Found 22 works for chunk: ['Decennial Census', 'American Housing Survey']
# Processing researcher 'Steven R Holloway' with 1 dataset terms.
#   Querying chunk: ['Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5045689985&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Decennial Census"),authorships.author.id:https://openalex.org/A5045689985&sort=relevance_score:desc&per_page=50
#     Found 4 works for chunk: ['Decennial Census']
# Processing researcher 'Thomas Foster' with 2 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5072233997&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Master Address File Extract', 'Decennial Census']
# Processing researcher 'Todd K Gardner' with 3 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5054989239&sort=relevance_score:desc&per_page=50
# API Request: https://api.openalex.org/works?page=2&filter=default.search:("Master Address File Extract" OR "Address Control FIle" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5054989239&sort=relevance_score:desc&per_page=50
#     Found 6 works for chunk: ['Master Address File Extract', 'Address Control FIle', 'Decennial Census']
# Processing researcher 'Tongyang Yang' with 2 dataset terms.
#   Querying chunk: ['Master Address File Extract', 'Decennial Census']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Master Address File Extract" OR "Decennial Census"),authorships.author.id:https://openalex.org/A5011567376&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Master Address File Extract', 'Decennial Census']
# Processing researcher 'Victor A Shlychkov' with 2 dataset terms.
#   No OpenAlex ID found for researcher 'Victor A Shlychkov'. Skipping.
# Processing researcher 'Weiliang Tan' with 3 dataset terms.
#   Querying chunk: ['Auxiliary Establishment - ES9200', 'Business Enterprise Research and Development Survey (BERD)', 'Census of Construction Industries']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Auxiliary Establishment - ES9200" OR "Business Enterprise Research and Development Survey (BERD)" OR "Census of Construction Industries"),authorships.author.id:https://openalex.org/A5087653699&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Auxiliary Establishment - ES9200', 'Business Enterprise Research and Development Survey (BERD)', 'Census of Construction Industries']
# Processing researcher 'Yupeng Wang' with 21 dataset terms.
#   Querying chunk: ['Annual Capital Expenditures Survey', 'Intellectual Property Public Patent Data - No PII', 'Ownership Change Database', 'Business Enterprise Research and Development Survey (BERD)']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Annual Capital Expenditures Survey" OR "Intellectual Property Public Patent Data - No PII" OR "Ownership Change Database" OR "Business Enterprise Research and Development Survey (BERD)"),authorships.author.id:https://openalex.org/A5100379840&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Annual Capital Expenditures Survey', 'Intellectual Property Public Patent Data - No PII', 'Ownership Change Database', 'Business Enterprise Research and Development Survey (BERD)']
#   Querying chunk: ['Census of Mining', 'Census of Services', 'Quarterly Financial Report Census Years', 'Census of Construction Industries']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Census of Mining" OR "Census of Services" OR "Quarterly Financial Report Census Years" OR "Census of Construction Industries"),authorships.author.id:https://openalex.org/A5100379840&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Census of Mining', 'Census of Services', 'Quarterly Financial Report Census Years', 'Census of Construction Industries']
#   Querying chunk: ['Integrated Longitudinal Business Database', 'Census of Finance, Insurance, and Real Estate', 'Auxiliary Establishment - ES9200', 'Census of Retail Trade']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Integrated Longitudinal Business Database" OR "Census of Finance, Insurance, and Real Estate" OR "Auxiliary Establishment - ES9200" OR "Census of Retail Trade"),authorships.author.id:https://openalex.org/A5100379840&sort=relevance_score:desc&per_page=50
# Error querying for datasets '"Integrated Longitudinal Business Database" OR "Census of Finance, Insurance, and Real Estate" OR "Auxiliary Establishment - ES9200" OR "Census of Retail Trade"' and author 'https://openalex.org/A5100379840': 403 Client Error: FORBIDDEN for url: https://api.openalex.org/works?page=1&filter=default.search%3A%28%22Integrated+Longitudinal+Business+Database%22+OR+%22Census+of+Finance%2C+Insurance%2C+and+Real+Estate%22+OR+%22Auxiliary+Establishment+-+ES9200%22+OR+%22Census+of+Retail+Trade%22%29%2Cauthorships.author.id%3Ahttps%3A%2F%2Fopenalex.org%2FA5100379840&sort=relevance_score%3Adesc&per_page=50
#     Found 0 works for chunk: ['Integrated Longitudinal Business Database', 'Census of Finance, Insurance, and Real Estate', 'Auxiliary Establishment - ES9200', 'Census of Retail Trade']
#   Querying chunk: ['Survey of Industrial Research and Development', 'Census of Manufactures', 'Standard Statistical Establishment Listing', 'Census of Wholesale Trade']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Survey of Industrial Research and Development" OR "Census of Manufactures" OR "Standard Statistical Establishment Listing" OR "Census of Wholesale Trade"),authorships.author.id:https://openalex.org/A5100379840&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['Survey of Industrial Research and Development', 'Census of Manufactures', 'Standard Statistical Establishment Listing', 'Census of Wholesale Trade']
#   Querying chunk: ['Longitudinal Business Database - With EIN and Revenue', 'Census of Transportation, Communications, and Utilities', 'Compustat-SSEL Bridge', 'Annual Survey of Manufactures']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("Longitudinal Business Database - With EIN and Revenue" OR "Census of Transportation, Communications, and Utilities" OR "Compustat-SSEL Bridge" OR "Annual Survey of Manufactures"),authorships.author.id:https://openalex.org/A5100379840&sort=relevance_score:desc&per_page=50
# Error querying for datasets '"Longitudinal Business Database - With EIN and Revenue" OR "Census of Transportation, Communications, and Utilities" OR "Compustat-SSEL Bridge" OR "Annual Survey of Manufactures"' and author 'https://openalex.org/A5100379840': 403 Client Error: FORBIDDEN for url: https://api.openalex.org/works?page=1&filter=default.search%3A%28%22Longitudinal+Business+Database+-+With+EIN+and+Revenue%22+OR+%22Census+of+Transportation%2C+Communications%2C+and+Utilities%22+OR+%22Compustat-SSEL+Bridge%22+OR+%22Annual+Survey+of+Manufactures%22%29%2Cauthorships.author.id%3Ahttps%3A%2F%2Fopenalex.org%2FA5100379840&sort=relevance_score%3Adesc&per_page=50
#     Found 0 works for chunk: ['Longitudinal Business Database - With EIN and Revenue', 'Census of Transportation, Communications, and Utilities', 'Compustat-SSEL Bridge', 'Annual Survey of Manufactures']
#   Querying chunk: ['NBER-CES Manufacturing Industry Database (Public Use Dataset)']
# API Request: https://api.openalex.org/works?page=1&filter=default.search:("NBER-CES Manufacturing Industry Database (Public Use Dataset)"),authorships.author.id:https://openalex.org/A5100379840&sort=relevance_score:desc&per_page=50
#     Found 0 works for chunk: ['NBER-CES Manufacturing Industry Database (Public Use Dataset)']
# Saved 61 matching records to openalex_researcher_datasets_matches_test.csv

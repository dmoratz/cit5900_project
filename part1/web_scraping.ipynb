# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

BASE_URL = "https://ideas.repec.org"
LIST_PAGE = "https://ideas.repec.org/s/cen/wpaper.html"
HEADERS = {"User-Agent": "FSRDC-Project-Bot/1.0"}

# Load researchers from All_Metadata
RESEARCHER_URL = "https://raw.githubusercontent.com/dingkaihua/fsrdc-external-census-projects/master/metadata/All_Metadata.csv"
df_meta = pd.read_csv(RESEARCHER_URL)
researcher_cols = [col for col in df_meta.columns if col.startswith("Researcher")]
researchers = set()
for col in researcher_cols:
    researchers.update(df_meta[col].dropna().str.strip())

normalized_researchers = {re.sub(r'[^\w\s]', '', name).strip().lower() for name in researchers}

def normalize_name(name):
    return re.sub(r'[^\w\s]', '', name).strip().lower()

def match_researcher(authors):
    if authors == "N/A": return ""
    for author in authors.split(";"):
        if normalize_name(author) in normalized_researchers:
            return author.strip()
    return ""

def clean_authors(authors):
    return [a.strip() for a in authors if a.strip() and not a.lower().startswith("registered")]

def find_flags(abstract):
    if not abstract or abstract == "N/A":
        return {
            "mention_acknowledgment": False,
            "mention_restricted_data": False,
            "mention_disclosure_review": False,
            "mention_rdc": False,
            "matched_dataset_terms": ""
        }

    abstract_lower = abstract.lower()

    ack_patterns = ["census bureau", "fsrdc", "federal statistical research data center"]
    restricted_data = ["census", "irs", "bea", "restricted microdata", "confidential data"]
    disclosure_patterns = ["disclosure review", "confidentiality review", "reviewed for disclosure"]
    rdc_patterns = ["michigan rdc", "texas rdc", "chicago rdc", "minnesota rdc"]

    datasets = [
        "annual survey of manufactures",
        "census of construction industries",
        "census of finance, insurance, and real estate",
        "american community survey",
        "current population survey",
        "medical expenditure panel survey",
        "integrated longitudinal business database"
    ]
    matched_datasets = [d for d in datasets if d in abstract_lower]

    return {
        "mention_acknowledgment": any(p in abstract_lower for p in ack_patterns),
        "mention_restricted_data": any(p in abstract_lower for p in restricted_data),
        "mention_disclosure_review": any(p in abstract_lower for p in disclosure_patterns),
        "mention_rdc": any(p in abstract_lower for p in rdc_patterns),
        "matched_dataset_terms": "; ".join(matched_datasets)
    }

def get_paper_links():
    resp = requests.get(LIST_PAGE, headers=HEADERS)
    soup = BeautifulSoup(resp.text, "html.parser")
    return [BASE_URL + a['href'] for a in soup.select("ul.paperlist li a") if a['href'].startswith("/p/cen/wpaper/")]

def scrape_repec(url):
    resp = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(resp.text, "html.parser")
    title = soup.find("h1").text.strip() if soup.find("h1") else "N/A"
    abstract = soup.find("div", id="abstract-body")
    abstract = abstract.text.strip() if abstract else "N/A"
    authors = []
    ul = soup.find("ul", id="authorlist")
    if ul:
        authors += [li.text for li in ul.find_all("li")]
    reg_div = soup.find("div", id="registered-authors")
    if reg_div:
        authors += [a.text for a in reg_div.find_all("a")]
    authors = "; ".join(clean_authors(authors)) if authors else "N/A"
    year = re.search(r'/([0-9]{2})-', url)
    year = "20" + year.group(1) if year else "N/A"
    return {"title": title, "abstract": abstract, "authors": authors, "year": year, "url": url}

def query_openalex(title):
    try:
        resp = requests.get("https://api.openalex.org/works", params={"search": title, "per_page": 1}, headers=HEADERS)
        data = resp.json()
        if data.get("results"):
            r = data["results"][0]
            return {
                "doi": r.get("doi", "N/A"),
                "publication_date": r.get("publication_date", "N/A"),
                "cited_by_count": r.get("cited_by_count", "N/A"),
                "affiliations": "; ".join(
                    aff["institution"]["display_name"]
                    for auth in r.get("authorships", [])
                    for aff in auth.get("institutions", [])
                    if aff.get("institution")
                ) or "N/A",
                "source_display_name": r.get("host_venue", {}).get("display_name", "N/A"),
                "type_crossref": r.get("type", "N/A"),
                "topics": "; ".join(t["display_name"] for t in r.get("concepts", []))
            }
    except:
        pass
    return {
        "doi": "N/A", "publication_date": "N/A", "cited_by_count": "N/A",
        "affiliations": "N/A", "source_display_name": "N/A", "type_crossref": "N/A", "topics": "N/A"
    }

results = []
for i, link in enumerate(get_paper_links()):
    print(f"[{i+1}] {link}")
    base = scrape_repec(link)
    flags = find_flags(base["abstract"])
    if not any([
        flags["mention_acknowledgment"], flags["mention_disclosure_review"],
        flags["mention_restricted_data"], flags["mention_rdc"],
        flags["matched_dataset_terms"]
    ]):
        print("skipped (no FSRDC relevance)")
        continue
    matched = match_researcher(base["authors"])
    if not matched:
        print("skipped (no researcher match)")
        continue
    enriched = query_openalex(base["title"])
    results.append({
        **base, **enriched, **flags,
        "researcher": matched
    })
    time.sleep(1.2)

# Export
cols = [
    "title", "doi", "abstract", "year", "publication_date", "cited_by_count",
    "authors", "affiliations", "topics", "source_display_name", "type_crossref",
    "researcher", "matched_dataset_terms",
    "mention_acknowledgment", "mention_restricted_data", "mention_disclosure_review",
    "mention_rdc"
]
pd.DataFrame(results)[cols].to_csv("web_scraping_full_output.csv", index=False)
print("\n Done! Saved to 'web_scraping_full_output.csv'")
# Out:
# [1] https://ideas.repec.org/p/cen/wpaper/25-19.html
# skipped (no researcher match)
# [2] https://ideas.repec.org/p/cen/wpaper/25-18.html
# skipped (no FSRDC relevance)
# [3] https://ideas.repec.org/p/cen/wpaper/25-16.html
# skipped (no researcher match)
# [4] https://ideas.repec.org/p/cen/wpaper/25-15.html
# [5] https://ideas.repec.org/p/cen/wpaper/25-14.html
# [6] https://ideas.repec.org/p/cen/wpaper/25-13.html
# skipped (no researcher match)
# [7] https://ideas.repec.org/p/cen/wpaper/25-12.html
# skipped (no FSRDC relevance)
# [8] https://ideas.repec.org/p/cen/wpaper/25-11.html
# skipped (no FSRDC relevance)
# [9] https://ideas.repec.org/p/cen/wpaper/25-10.html
# skipped (no researcher match)
# [10] https://ideas.repec.org/p/cen/wpaper/25-09.html
# skipped (no FSRDC relevance)
# [11] https://ideas.repec.org/p/cen/wpaper/25-08.html
# skipped (no FSRDC relevance)
# [12] https://ideas.repec.org/p/cen/wpaper/25-07.html
# skipped (no researcher match)
# [13] https://ideas.repec.org/p/cen/wpaper/25-06.html
# [14] https://ideas.repec.org/p/cen/wpaper/25-05.html
# skipped (no researcher match)
# [15] https://ideas.repec.org/p/cen/wpaper/25-04.html
# skipped (no FSRDC relevance)
# [16] https://ideas.repec.org/p/cen/wpaper/25-03.html
# skipped (no researcher match)
# [17] https://ideas.repec.org/p/cen/wpaper/25-02.html
# [18] https://ideas.repec.org/p/cen/wpaper/25-01.html
# skipped (no researcher match)
# [19] https://ideas.repec.org/p/cen/wpaper/24-78.html
# [20] https://ideas.repec.org/p/cen/wpaper/24-77.html
# skipped (no FSRDC relevance)
# [21] https://ideas.repec.org/p/cen/wpaper/24-76.html
# [22] https://ideas.repec.org/p/cen/wpaper/24-75.html
# [23] https://ideas.repec.org/p/cen/wpaper/24-74.html
# [24] https://ideas.repec.org/p/cen/wpaper/24-73.html
# skipped (no researcher match)
# [25] https://ideas.repec.org/p/cen/wpaper/24-72.html
# skipped (no researcher match)
# [26] https://ideas.repec.org/p/cen/wpaper/24-71.html
# skipped (no researcher match)
# [27] https://ideas.repec.org/p/cen/wpaper/24-70.html
# [28] https://ideas.repec.org/p/cen/wpaper/24-69.html
# skipped (no FSRDC relevance)
# [29] https://ideas.repec.org/p/cen/wpaper/24-68.html
# skipped (no FSRDC relevance)
# [30] https://ideas.repec.org/p/cen/wpaper/24-67.html
# skipped (no FSRDC relevance)
# [31] https://ideas.repec.org/p/cen/wpaper/24-66.html
# [32] https://ideas.repec.org/p/cen/wpaper/24-65.html
# [33] https://ideas.repec.org/p/cen/wpaper/24-64.html
# skipped (no FSRDC relevance)
# [34] https://ideas.repec.org/p/cen/wpaper/24-63.html
# skipped (no FSRDC relevance)
# [35] https://ideas.repec.org/p/cen/wpaper/24-62.html
# skipped (no FSRDC relevance)
# [36] https://ideas.repec.org/p/cen/wpaper/24-61.html
# skipped (no FSRDC relevance)
# [37] https://ideas.repec.org/p/cen/wpaper/24-60.html
# skipped (no researcher match)
# [38] https://ideas.repec.org/p/cen/wpaper/24-59.html
# skipped (no FSRDC relevance)
# [39] https://ideas.repec.org/p/cen/wpaper/24-58.html
# skipped (no researcher match)
# [40] https://ideas.repec.org/p/cen/wpaper/24-57.html
# [41] https://ideas.repec.org/p/cen/wpaper/24-56.html
# skipped (no researcher match)
# [42] https://ideas.repec.org/p/cen/wpaper/24-55.html
# skipped (no researcher match)
# [43] https://ideas.repec.org/p/cen/wpaper/24-54.html
# skipped (no FSRDC relevance)
# [44] https://ideas.repec.org/p/cen/wpaper/24-53.html
# skipped (no FSRDC relevance)
# [45] https://ideas.repec.org/p/cen/wpaper/24-52.html
# skipped (no FSRDC relevance)
# [46] https://ideas.repec.org/p/cen/wpaper/24-51.html
# [47] https://ideas.repec.org/p/cen/wpaper/24-50.html
# skipped (no researcher match)
# [48] https://ideas.repec.org/p/cen/wpaper/24-49.html
# [49] https://ideas.repec.org/p/cen/wpaper/24-48.html
# skipped (no researcher match)
# [50] https://ideas.repec.org/p/cen/wpaper/24-47.html
# skipped (no FSRDC relevance)
# [51] https://ideas.repec.org/p/cen/wpaper/24-46.html
# [52] https://ideas.repec.org/p/cen/wpaper/24-45.html
# skipped (no FSRDC relevance)
# [53] https://ideas.repec.org/p/cen/wpaper/24-44.html
# skipped (no FSRDC relevance)
# [54] https://ideas.repec.org/p/cen/wpaper/24-43.html
# skipped (no FSRDC relevance)
# [55] https://ideas.repec.org/p/cen/wpaper/24-42.html
# skipped (no FSRDC relevance)
# [56] https://ideas.repec.org/p/cen/wpaper/24-41.html
# skipped (no FSRDC relevance)
# [57] https://ideas.repec.org/p/cen/wpaper/24-40.html
# skipped (no FSRDC relevance)
# [58] https://ideas.repec.org/p/cen/wpaper/24-39.html
# [59] https://ideas.repec.org/p/cen/wpaper/24-38.html
# skipped (no FSRDC relevance)
# [60] https://ideas.repec.org/p/cen/wpaper/24-37.html
# skipped (no FSRDC relevance)
# [61] https://ideas.repec.org/p/cen/wpaper/24-36.html
# skipped (no FSRDC relevance)
# [62] https://ideas.repec.org/p/cen/wpaper/24-35.html
# skipped (no FSRDC relevance)
# [63] https://ideas.repec.org/p/cen/wpaper/24-34.html
# skipped (no researcher match)
# [64] https://ideas.repec.org/p/cen/wpaper/24-33.html
# skipped (no FSRDC relevance)
# [65] https://ideas.repec.org/p/cen/wpaper/24-32.html
# skipped (no researcher match)
# [66] https://ideas.repec.org/p/cen/wpaper/24-31.html
# skipped (no researcher match)
# [67] https://ideas.repec.org/p/cen/wpaper/24-30.html
# skipped (no FSRDC relevance)
# [68] https://ideas.repec.org/p/cen/wpaper/24-29.html
# skipped (no FSRDC relevance)
# [69] https://ideas.repec.org/p/cen/wpaper/24-28.html
# skipped (no researcher match)
# [70] https://ideas.repec.org/p/cen/wpaper/24-27.html
# [71] https://ideas.repec.org/p/cen/wpaper/24-26.html
# skipped (no researcher match)
# [72] https://ideas.repec.org/p/cen/wpaper/24-25.html
# skipped (no researcher match)
# [73] https://ideas.repec.org/p/cen/wpaper/24-24.html
# skipped (no FSRDC relevance)
# [74] https://ideas.repec.org/p/cen/wpaper/24-23.html
# skipped (no FSRDC relevance)
# [75] https://ideas.repec.org/p/cen/wpaper/24-22.html
# [76] https://ideas.repec.org/p/cen/wpaper/24-21.html
# [77] https://ideas.repec.org/p/cen/wpaper/24-20.html
# skipped (no FSRDC relevance)
# [78] https://ideas.repec.org/p/cen/wpaper/24-19.html
# [79] https://ideas.repec.org/p/cen/wpaper/24-18.html
# [80] https://ideas.repec.org/p/cen/wpaper/24-17.html
# [81] https://ideas.repec.org/p/cen/wpaper/24-16.html
# skipped (no FSRDC relevance)
# [82] https://ideas.repec.org/p/cen/wpaper/24-15.html
# [83] https://ideas.repec.org/p/cen/wpaper/24-14.html
# skipped (no researcher match)
# [84] https://ideas.repec.org/p/cen/wpaper/24-13.html
# skipped (no researcher match)
# [85] https://ideas.repec.org/p/cen/wpaper/24-12.html
# skipped (no FSRDC relevance)
# [86] https://ideas.repec.org/p/cen/wpaper/24-11.html
# [87] https://ideas.repec.org/p/cen/wpaper/24-10.html
# [88] https://ideas.repec.org/p/cen/wpaper/24-09.html
# skipped (no FSRDC relevance)
# [89] https://ideas.repec.org/p/cen/wpaper/24-08.html
# skipped (no researcher match)
# [90] https://ideas.repec.org/p/cen/wpaper/24-07.html
# skipped (no FSRDC relevance)
# [91] https://ideas.repec.org/p/cen/wpaper/24-06.html
# skipped (no FSRDC relevance)
# [92] https://ideas.repec.org/p/cen/wpaper/24-05.html
# skipped (no FSRDC relevance)
# [93] https://ideas.repec.org/p/cen/wpaper/24-04.html
# [94] https://ideas.repec.org/p/cen/wpaper/24-03.html
# skipped (no FSRDC relevance)
# [95] https://ideas.repec.org/p/cen/wpaper/24-02.html
# skipped (no researcher match)
# [96] https://ideas.repec.org/p/cen/wpaper/24-01.html
# skipped (no researcher match)
# [97] https://ideas.repec.org/p/cen/wpaper/23-65.html
# skipped (no FSRDC relevance)
# [98] https://ideas.repec.org/p/cen/wpaper/23-64.html
# skipped (no FSRDC relevance)
# [99] https://ideas.repec.org/p/cen/wpaper/23-63.html
# [100] https://ideas.repec.org/p/cen/wpaper/23-62.html
# [101] https://ideas.repec.org/p/cen/wpaper/23-61.html
# skipped (no FSRDC relevance)
# [102] https://ideas.repec.org/p/cen/wpaper/23-60.html
# [103] https://ideas.repec.org/p/cen/wpaper/23-59.html
# skipped (no FSRDC relevance)
# [104] https://ideas.repec.org/p/cen/wpaper/23-58.html
# skipped (no researcher match)
# [105] https://ideas.repec.org/p/cen/wpaper/23-57.html
# [106] https://ideas.repec.org/p/cen/wpaper/23-56.html
# skipped (no FSRDC relevance)
# [107] https://ideas.repec.org/p/cen/wpaper/23-55.html
# skipped (no FSRDC relevance)
# [108] https://ideas.repec.org/p/cen/wpaper/23-54.html
# skipped (no FSRDC relevance)
# [109] https://ideas.repec.org/p/cen/wpaper/23-53.html
# skipped (no FSRDC relevance)
# [110] https://ideas.repec.org/p/cen/wpaper/23-52.html
# [111] https://ideas.repec.org/p/cen/wpaper/23-51.html
# [112] https://ideas.repec.org/p/cen/wpaper/23-50.html
# [113] https://ideas.repec.org/p/cen/wpaper/23-49.html
# [114] https://ideas.repec.org/p/cen/wpaper/23-48.html
# skipped (no FSRDC relevance)
# [115] https://ideas.repec.org/p/cen/wpaper/23-47.html
# [116] https://ideas.repec.org/p/cen/wpaper/23-46.html
# skipped (no researcher match)
# [117] https://ideas.repec.org/p/cen/wpaper/23-45.html
# skipped (no FSRDC relevance)
# [118] https://ideas.repec.org/p/cen/wpaper/23-44.html
# skipped (no researcher match)
# [119] https://ideas.repec.org/p/cen/wpaper/23-43.html
# skipped (no FSRDC relevance)
# [120] https://ideas.repec.org/p/cen/wpaper/23-42.html
# skipped (no researcher match)
# [121] https://ideas.repec.org/p/cen/wpaper/23-41.html
# skipped (no FSRDC relevance)
# [122] https://ideas.repec.org/p/cen/wpaper/23-40.html
# skipped (no FSRDC relevance)
# [123] https://ideas.repec.org/p/cen/wpaper/23-39.html
# [124] https://ideas.repec.org/p/cen/wpaper/23-38.html
# skipped (no FSRDC relevance)
# [125] https://ideas.repec.org/p/cen/wpaper/23-37.html
# [126] https://ideas.repec.org/p/cen/wpaper/23-36.html
# [127] https://ideas.repec.org/p/cen/wpaper/23-35.html
# skipped (no researcher match)
# [128] https://ideas.repec.org/p/cen/wpaper/23-34.html
# skipped (no FSRDC relevance)
# [129] https://ideas.repec.org/p/cen/wpaper/23-33.html
# skipped (no researcher match)
# [130] https://ideas.repec.org/p/cen/wpaper/23-32.html
# skipped (no researcher match)
# [131] https://ideas.repec.org/p/cen/wpaper/23-31.html
# [132] https://ideas.repec.org/p/cen/wpaper/23-30.html
# skipped (no researcher match)
# [133] https://ideas.repec.org/p/cen/wpaper/23-29.html
# skipped (no FSRDC relevance)
# [134] https://ideas.repec.org/p/cen/wpaper/23-28.html
# skipped (no researcher match)
# [135] https://ideas.repec.org/p/cen/wpaper/23-27.html
# skipped (no FSRDC relevance)
# [136] https://ideas.repec.org/p/cen/wpaper/23-26.html
# skipped (no FSRDC relevance)
# [137] https://ideas.repec.org/p/cen/wpaper/23-25.html
# skipped (no researcher match)
# [138] https://ideas.repec.org/p/cen/wpaper/23-24.html
# skipped (no FSRDC relevance)
# [139] https://ideas.repec.org/p/cen/wpaper/23-23.html
# skipped (no FSRDC relevance)
# [140] https://ideas.repec.org/p/cen/wpaper/23-22.html
# skipped (no researcher match)
# [141] https://ideas.repec.org/p/cen/wpaper/23-21.html
# [142] https://ideas.repec.org/p/cen/wpaper/23-20.html
# [143] https://ideas.repec.org/p/cen/wpaper/23-19.html
# skipped (no researcher match)
# [144] https://ideas.repec.org/p/cen/wpaper/23-18.html
# skipped (no FSRDC relevance)
# [145] https://ideas.repec.org/p/cen/wpaper/23-17.html
# [146] https://ideas.repec.org/p/cen/wpaper/23-16.html
# skipped (no FSRDC relevance)
# [147] https://ideas.repec.org/p/cen/wpaper/23-15.html
# skipped (no researcher match)
# [148] https://ideas.repec.org/p/cen/wpaper/23-14.html
# [149] https://ideas.repec.org/p/cen/wpaper/23-13.html
# skipped (no FSRDC relevance)
# [150] https://ideas.repec.org/p/cen/wpaper/23-12.html
# skipped (no researcher match)
# [151] https://ideas.repec.org/p/cen/wpaper/23-11.html
# skipped (no researcher match)
# [152] https://ideas.repec.org/p/cen/wpaper/23-10.html
# [153] https://ideas.repec.org/p/cen/wpaper/23-09.html
# skipped (no FSRDC relevance)
# [154] https://ideas.repec.org/p/cen/wpaper/23-08.html
# skipped (no researcher match)
# [155] https://ideas.repec.org/p/cen/wpaper/23-07.html
# [156] https://ideas.repec.org/p/cen/wpaper/23-06.html
# skipped (no FSRDC relevance)
# [157] https://ideas.repec.org/p/cen/wpaper/23-05.html
# skipped (no FSRDC relevance)
# [158] https://ideas.repec.org/p/cen/wpaper/23-04.html
# skipped (no researcher match)
# [159] https://ideas.repec.org/p/cen/wpaper/23-03.html
# skipped (no FSRDC relevance)
# [160] https://ideas.repec.org/p/cen/wpaper/23-02.html
# skipped (no FSRDC relevance)
# [161] https://ideas.repec.org/p/cen/wpaper/23-01.html
# [162] https://ideas.repec.org/p/cen/wpaper/22-59.html
# [163] https://ideas.repec.org/p/cen/wpaper/22-58.html
# skipped (no researcher match)
# [164] https://ideas.repec.org/p/cen/wpaper/22-57.html
# skipped (no FSRDC relevance)
# [165] https://ideas.repec.org/p/cen/wpaper/22-56.html
# [166] https://ideas.repec.org/p/cen/wpaper/22-55.html
# skipped (no FSRDC relevance)
# [167] https://ideas.repec.org/p/cen/wpaper/22-54.html
# [168] https://ideas.repec.org/p/cen/wpaper/22-53.html
# [169] https://ideas.repec.org/p/cen/wpaper/22-52.html
# skipped (no researcher match)
# [170] https://ideas.repec.org/p/cen/wpaper/22-51.html
# skipped (no researcher match)
# [171] https://ideas.repec.org/p/cen/wpaper/22-50.html
# skipped (no researcher match)
# [172] https://ideas.repec.org/p/cen/wpaper/22-49.html
# [173] https://ideas.repec.org/p/cen/wpaper/22-48.html
# skipped (no FSRDC relevance)
# [174] https://ideas.repec.org/p/cen/wpaper/22-47.html
# skipped (no FSRDC relevance)
# [175] https://ideas.repec.org/p/cen/wpaper/22-46.html
# skipped (no FSRDC relevance)
# [176] https://ideas.repec.org/p/cen/wpaper/22-45.html
# [177] https://ideas.repec.org/p/cen/wpaper/22-44.html
# [178] https://ideas.repec.org/p/cen/wpaper/22-43.html
# [179] https://ideas.repec.org/p/cen/wpaper/22-42.html
# skipped (no FSRDC relevance)
# [180] https://ideas.repec.org/p/cen/wpaper/22-41.html
# skipped (no researcher match)
# [181] https://ideas.repec.org/p/cen/wpaper/22-40.html
# [182] https://ideas.repec.org/p/cen/wpaper/22-39.html
# [183] https://ideas.repec.org/p/cen/wpaper/22-38.html
# [184] https://ideas.repec.org/p/cen/wpaper/22-37.html
# [185] https://ideas.repec.org/p/cen/wpaper/22-36.html
# skipped (no FSRDC relevance)
# [186] https://ideas.repec.org/p/cen/wpaper/22-35.html
# skipped (no FSRDC relevance)
# [187] https://ideas.repec.org/p/cen/wpaper/22-34.html
# [188] https://ideas.repec.org/p/cen/wpaper/22-33.html
# skipped (no FSRDC relevance)
# [189] https://ideas.repec.org/p/cen/wpaper/22-32.html
# skipped (no researcher match)
# [190] https://ideas.repec.org/p/cen/wpaper/22-31.html
# [191] https://ideas.repec.org/p/cen/wpaper/22-30.html
# skipped (no FSRDC relevance)
# [192] https://ideas.repec.org/p/cen/wpaper/22-29.html
# [193] https://ideas.repec.org/p/cen/wpaper/22-28.html
# [194] https://ideas.repec.org/p/cen/wpaper/22-27.html
# [195] https://ideas.repec.org/p/cen/wpaper/22-26.html
# skipped (no FSRDC relevance)
# [196] https://ideas.repec.org/p/cen/wpaper/22-25.html
# skipped (no FSRDC relevance)
# [197] https://ideas.repec.org/p/cen/wpaper/22-24.html
# skipped (no researcher match)
# [198] https://ideas.repec.org/p/cen/wpaper/22-23.html
# skipped (no FSRDC relevance)
# [199] https://ideas.repec.org/p/cen/wpaper/22-22.html
#
#  Done! Saved to 'web_scraping_full_output.csv'

# %%
def test_normalize_name():
    assert normalize_name("John A. Smith") == "john a smith"
    assert normalize_name(" Jane-Doe ") == "janedoe"
    assert normalize_name("Dr. María-José, Jr.") == "dr maríajosé jr"
    print("test_normalize_name passed.")

def test_match_researcher_custom():
    # Mock a mini researcher set
    global normalized_researchers
    normalized_researchers = {"john doe", "jane smith", "amy lin"}

    assert match_researcher("John Doe; Emily Zhang") == "John Doe"
    assert match_researcher("Someone Else; Amy Lin") == "Amy Lin"
    assert match_researcher("Unknown; Another") == ""
    assert match_researcher("N/A") == ""
    print("test_match_researcher passed.")

def test_clean_authors():
    dirty_list = ["John Doe", "Registered:", "", "Jane Smith", "  "]
    cleaned = clean_authors(dirty_list)
    print(cleaned)
    assert cleaned == ["John Doe", "Jane Smith"]
    print("test_clean_authors passed.")

def test_find_flags():
    abstract = (
        "This study uses the Census Bureau's restricted microdata from the American Community Survey. "
        "All analysis was reviewed for disclosure. Data were accessed via the Michigan RDC."
    )
    flags = find_flags(abstract)
    assert flags["mention_acknowledgment"] is True
    assert flags["mention_restricted_data"] is True
    assert flags["mention_disclosure_review"] is True
    assert flags["mention_rdc"] is True
    assert "american community survey" in flags["matched_dataset_terms"].lower()

    empty = find_flags("This is unrelated to government datasets.")
    assert not any([empty[k] for k in empty if k != "matched_dataset_terms"])
    assert empty["matched_dataset_terms"] == ""
    print("test_find_flags passed.")

test_normalize_name()
test_match_researcher_custom()
test_clean_authors()
test_find_flags()
print("All tests passed!\n")
# Out:
# test_normalize_name passed.
# test_match_researcher passed.
# ['John Doe', 'Jane Smith']
# test_clean_authors passed.
# test_find_flags passed.
# All tests passed!
